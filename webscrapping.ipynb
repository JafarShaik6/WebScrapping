# %% [markdown]
# ## Problem Statement :-
# #### Scrape House Prices from the Magic bricks Website and map the localities to a unique set of zip-codes in that city. Python modules are available to solve the latter half of the task.

# %% [markdown]
# Web-Scraping is often used as a tool to collect the data when no real-time data available for the analysis. First of all, we are going to collect all the search results from magic bricks websites in Hyderabad.All the data is neatly arranged.
#
# Before we actually begin scraping the data, we need to decide on what features need to be scraped from the website. In the current example, we will be collecting,
# No Bedrooms.
#
# No Bathrooms.
#
# Type of Furnishing.
#
# The Tennants Preferred.
#
# The Area of the House in sqft.
#
# The locality of the House.
#
# Price or Rent.

# %%
# importing libraries
import re
import time
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import urlopen,Request

# %% [markdown]
# Some websites automatically block any kind of scraping, and that’s why we’ll define a header to pass along the get command, which will basically make our queries to the website look like they are coming from an actual browser.

# %%
headers = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36'})
url = "https://www.magicbricks.com/property-for-rent/residential-real-estate?proptype=Multistorey-Apartment,Builder-Floor-Apartment,Penthouse,Studio-Apartment,Service-Apartment&cityName=Hyderabad&BudgetMin=5000&BudgetMax=50000&page="

# %% [markdown]
# After collecting the webpage data as a list of containers, we can see that data pertaining to each field is stored in <span> tags in each of the page_containers. We can write a script to collect all the span tags of each page_container, extract the data and loop it over the entire page_containers.
#
# The logic remains the same for all the fields except Locality where the locality needs to be extracted from a string of characters and little tricky to get.I have used regular expressions to find the pattern which starts with ‘in’ and ends with a ‘number (\d)’ but this pattern is not uniform across the data, Some samples are also ending with spaces or with nothing at the end. So, I have used 3 patterns to get the locality data.

# %%
def house_price(url,headers):
    request = Request(url, headers=headers)
    response = urlopen(request)
    html = response.read()
    html_soup = BeautifulSoup(html , 'html.parser')
    house_container = html_soup.find_all('div', class_ = 'flex relative clearfix m-srp-card__container' )
    for container in range(len(house_container)) :
        first  = house_container[container].find_all('span')
        second = house_container[container].find_all('div',class_ = 'm-srp-card__summary__info')
        Price_  = first[1].text.replace('\n','')
        Price.append((Price_))
        Bedrooms_   = first[3].text.replace('\n','')
        Bedrooms.append((Bedrooms_))
        try:
            Bathrooms_  = second[4].text.replace('\n','')
            Bathrooms.append(Bathrooms_)
        except :
            Bathrooms.append('NaN')
        try:
            Area_       = first[4].text.replace('\n','')
            Area.append((Area_))
        except:
            Area.append(('NaN'))
        Furnishing_ = second[1].text.replace('\n','')
        Furnishing.append(Furnishing_)
        try:
            Tennants_   = second[2].text.replace('\n','')
            Tennants.append(Tennants_)
        except:
            Tennants.append('NaN')
        try :
            Locality_0  = house_container[container].find_all('span')[2]
            Locality_1 = Locality_0.text.replace('\n',' ')
            Locality_2 = re.search(r'in(.+?)\d', Locality_1)
            if Locality_2 is None :
                Locality_2 = re.search(r'in(.+?),',Locality_1)
            if Locality_2 is None :
                Locality_2 = re.search(r'in(.+?) ',Locality_1)
            Locality_  = Locality_2[1]
            Locality.append(Locality_)
        except:
            Locality.append(('NaN'))
        
    cols = ['Bedrooms', 'Bathrooms', 'Furnishing', 'Tennants', 'Area', 'Price','Locality']

    house_data = pd.DataFrame({'Bedrooms': Bedrooms,
                               'Bathrooms': Bathrooms,
                               'Furnishing': Furnishing,
                               'Tennants': Tennants,
                               'Area': Area,
                               'Price': Price,
                               'Locality':Locality})[cols]
    return house_data

# %%
Bedrooms = []
Bathrooms = []
Furnishing = []
Tennants = []
Locality = []
Area = []
Price = []

# %%
for i in range(1,40):
    url_ = url+str(i)
    house_data = house_price(url_,headers)

# %%
house_data.count()
# Out:
# Bedrooms      1171
# Bathrooms     1171
# Furnishing    1171
# Tennants      1171
# Area          1171
# Price         1171
# Locality      1171
# dtype: int64

# %%
house_data.to_csv('magics_brics_data.csv')

# %%
data = pd.read_csv('magics_brics_data.csv')

# %%
data.head(10)
# Out:
#    Unnamed: 0                 Bedrooms    Bathrooms      Furnishing  \
# 0           0  3 BHK Service Apartment            1     Unfurnished
# 1           1      1 BHK Builder Floor            1     Unfurnished
# 2           2          3 BHK Apartment            1  Semi-Furnished
# 3           3      2 BHK Builder Floor            1  Semi-Furnished
# 4           4          2 BHK Apartment            1     Unfurnished
# 5           5          3 BHK Apartment            2  Semi-Furnished
# 6           6          3 BHK Apartment            3  Semi-Furnished
# 7           7          2 BHK Apartment            1     Unfurnished
# 8           8      3 BHK Builder Floor  Immediately  Semi-Furnished
# 9           9          3 BHK Apartment  Immediately  Semi-Furnished
#
#            Tennants       Area   Price  \
# 0         Bachelors  1390 sqft  26,000
# 1  Bachelors/Family  read more  14,000
# 2            Family  1650 sqft  35,000
# 3         Bachelors  1200 sqft  22,000
# 4         Bachelors  1295 sqft  27,000
# 5  Bachelors/Family  1630 sqft  30,000
# 6  Bachelors/Family  2075 sqft  49,000
# 7  Bachelors/Family        NaN   8,000
# 8  Bachelors/Family  1339 sqft  22,000
# 9  Bachelors/Family  1800 sqft  22,000
#
#                                             Locality
# 0                                     Hafeezpet, NH
# 1                                 Amarnath Residency
# 2                                     Nanakram Guda
# 3                                     Jubilee Hills
# 4                                   Chandanagar, NH
# 5                                       Gopanapalli
# 6   Vajras Jasmine County, Gachibowli, Outer Ring...
# 7                                     Eastend Colony
# 8                                        Tolichowki
# 9                         Narsingi, Outer Ring Road

# %%
import requests
import logging
import time

logger = logging.getLogger("root")
logger.setLevel(logging.DEBUG)
ch = logging.StreamHandler()
ch.setLevel(logging.DEBUG)
logger.addHandler(ch)

# %% [markdown]
# ##### Script for mapping address to unique zip code using google api
#
# The script expects an input CSV file with a column that contains addresses. The default column name is “Address”, but we can specify different names in the configuration section of the script.
#
# The script will take each address and geocode it using the Google APIs, returning:
#
# the matching latitude and longitude,
# the cleaned and formatted address from Google,
# postcode of the matched address
# accuracy of the match,
# the “type” of the location – “street, neighbourhood, locality”
# google place ID,
# the number of results returned,
# the entire JSON response from Google can be requested.
#
#
# For Generating API look into the link https://developers.google.com/maps/documentation/geocoding/get-api-key

# %%
API_KEY = 'AIzaSyAmcECGL6FaRhdm4YGAZRZB4ZL3ukttEyA'
BACKOFF_TIME = 30
output_filename = 'output-magicbricks.csv'

# %%
address_column_name = "Locality"
RETURN_FULL_RESULTS = False

# %%
if address_column_name not in data.columns:
    raise ValueError("Missing Address column in input data")

# %%
addresses = data[address_column_name].tolist()

# %% [markdown]
# The script functionality is simple: there’s a central function “get_google_result()” that actually requests data from the Google API using the Python requests library, and then a wrapper around that to handle data backup and geocoding query limits.

# %%
def get_google_results(address, api_key=None, return_full_response=False):
    # Set up your Geocoding url
    geocode_url = "https://maps.googleapis.com/maps/api/geocode/json?address={}".format(address)
    #print(geocode_url)
    if api_key is not None:
        geocode_url = geocode_url + "&key={}".format(api_key)
        
    # Ping google for the reuslts:
    results = requests.get(geocode_url)
    # Results will be in JSON format - convert to dict using requests functionality
    results = results.json()
    
    # if there's no results or an error, return empty results.
    if len(results['results']) == 0:
        output = {
            "postcode": None
        }
    else:    
        answer = results['results'][0]
        output = {
            "postcode": ",".join([x['long_name'] for x in answer.get('address_components') 
                                  if 'postal_code' in x.get('types')])
        }
        
    # Append some other details:    
    output['status'] = results.get('status')
    if return_full_response is True:
        output['response'] = results
    
    return output

# %%
results = []
# Go through each address in turn
for address in addresses:
    # While the address geocoding is not finished:
    geocoded = False
    while geocoded is not True:
        # Geocode the address with google
        try:
            geocode_result = get_google_results(address, API_KEY, return_full_response=RETURN_FULL_RESULTS)
        except Exception as e:
            logger.exception(e)
            logger.error("Major error with {}".format(address))
            logger.error("Skipping!")
            geocoded = True
            
        # If we're over the API limit, backoff for a while and try again later.
        if geocode_result['status'] == 'OVER_QUERY_LIMIT':
            logger.info("Hit Query Limit! Backing off for a bit.")
            time.sleep(BACKOFF_TIME * 60) # sleep for 30 minutes
            geocoded = False
        else:
            # If we're ok with API use, save the results
            # Note that the results might be empty / non-ok - log this
            if geocode_result['status'] != 'OK':
                logger.warning("Error geocoding {}: {}".format(address, geocode_result['status']))
            logger.debug("Geocoded: {}: {}".format(address, geocode_result['status']))
            results.append(geocode_result)  
            
            geocoded = True

    # Print status every 100 addresses
    if len(results) % 100 == 0:
    	logger.info("Completed {} of {} address".format(len(results), len(addresses)))
        

# All done
logger.info("Finished geocoding all addresses")
# Write the full results to csv using the pandas library.
data1=pd.DataFrame(results)
# Out:
# Geocoded:  Hafeezpet, NH : OK
# Geocoded:  Amarnath Residency: OK
# Geocoded:  Nanakram Guda : OK
# Geocoded:  Jubilee Hills : OK
# Geocoded:  Chandanagar, NH : OK
# Geocoded:  Gopanapalli : OK
# Geocoded:  Vajras Jasmine County, Gachibowli, Outer Ring Road : OK
# Geocoded:  Eastend Colony: OK
# Geocoded:  Tolichowki : OK
# Geocoded:  Narsingi, Outer Ring Road : OK
# Geocoded:  Osman Nagar : OK
# Geocoded:  Vidyanagar, Adikmet : OK
# Geocoded:  Kukatpally Housing Board Colony, NH : OK
# Geocoded:  Narsingi, Outer Ring Road : OK
# Geocoded:  Puppalaguda : OK
# Geocoded:  My Home Avatar, Narsingi, Outer Ring Road : OK
# Geocoded:  Lanco Hills, Manikonda, Outer Ring Road : OK
# Geocoded:  Gachibowli: OK
# Geocoded:  Yapral : OK
# Geocoded:  Aditya Imperial Heights, Hafeezpet, NH : OK
# Geocoded:  Sai Ram Nagar Colony, Champapet, Koti : OK
# Geocoded:  Mantri Celestia, Gachibowli, Outer Ring Road : OK
# Geocoded:  Kistareddypet, Outer Ring Road : OK
# Geocoded:  Gks Habitat Royale, Yapral : OK
# Geocoded:  Bikshapathi Nagar, Hafeezpet : OK
# Geocoded:  Floatilla, Alkapur Township, Manikonda, Outer Ring Road : OK
# Geocoded:  Mantri Celestia, Gachibowli, Outer Ring Road : OK
# Geocoded:  Kondapur : OK
# Geocoded:  Dullapally, NH : OK
# Geocoded:  Lingampally-Serilingampally, NH : OK
# Geocoded:  Bachupally, Outer Ring Road : OK
# Geocoded:  Bachupally, Outer Ring Road : OK
# Geocoded:  Vista Homes: OK
# Geocoded:  Banjara Hills, NH : OK
# Geocoded:  Mythri Nagar, Hafeezpet, NH : OK
# Geocoded:  Kapra : OK
# Geocoded:  Bandlaguda Jagir : OK
# Geocoded:  Domalguda, Himayath Nagar, NH : OK
# Geocoded:  Financial District, Nanakram Guda : OK
# Geocoded:  Madhapur : OK
# Geocoded:  Kokapet, Outer Ring Road : OK
# Geocoded:  chandrayangutta hyderabad : OK
# Geocoded:  K P H B Phase : OK
# Geocoded:  Himayatnagar : OK
# Geocoded:  Alkapur Township, Manikonda, Outer Ring Road : OK
# Geocoded:  Chandanagar, NH : OK
# Geocoded:  Rajarajeshwari Nagar, Kondapur : OK
# Geocoded:  My Home Avatar, Narsingi, Outer Ring Road : OK
# Geocoded:  Mir Alam Tank, NH : OK
# Geocoded:  Medchal Road : OK
# Geocoded:  Banjara Hills, NH : OK
# Geocoded:  Kondapur: OK
# Geocoded:  Banjara Hills, NH : OK
# Geocoded:  Peerzadiguda, NH : OK
# Geocoded:  Kondapur: OK
# Geocoded:  Hakimpet-Hyderabad : OK
# Geocoded:  Banjara Hills, NH : OK
# Geocoded:  Sitaphalmandi, Padmarao Nagar : OK
# Geocoded:  Mohans Sai Signature, Nanakram Guda : OK
# Geocoded:  Kokapet, Outer Ring Road : OK
# Geocoded:  Khairatabad, NH : OK
# Geocoded:  Whitefields : OK
# Geocoded:  Appa junction : OK
# Geocoded:  Suvarna Valley, Miyapur, NH : OK
# Geocoded:  Sun City, Bandlaguda, Chevella Road : OK
# Geocoded:  Nallagandla, Serilingampally : OK
# Geocoded:  Aparna Kanopy Tulip, Kompally : OK
# Error geocoding  Raghuram A: ZERO_RESULTS
# Geocoded:  Raghuram A: ZERO_RESULTS
# Geocoded:  Jubilee: OK
# Geocoded:  Banjara Hills, NH : OK
# Geocoded:  Green Habitat, Kondapur : OK
# Geocoded:  Kukatpally, NH : OK
# Geocoded:  Haripuri colony : OK
# Geocoded:  Brindavan Residency, Domalguda, Himayath Nagar, NH : OK
# Geocoded:  Barkatpura, Kachiguda, NH : OK
# Geocoded:  My Home Avatar, Narsingi, Outer Ring Road : OK
# Geocoded:  Kavuri Hills: OK
# Geocoded:  My Home Avatar, Narsingi, Outer Ring Road : OK
# Geocoded:  Shankara Kranthi Apartment, Kavadiguda, NH : OK
# Geocoded:  Hyder Nagar, NH : OK
# Geocoded:  Kondapur: OK
# Geocoded:  Chandanagar, NH : OK
# Geocoded:  Srinagar Colony, Old Malakpet, NH : OK
# Geocoded:  Old Nallakunta, New Nallakunta : OK
# Geocoded:  Bandlaguda Jagir : OK
# Geocoded:  Srinivas Nagar, Rhoda Mistri Nagar : OK
# Geocoded:  Shamshabad : OK
# Geocoded:  Gajularamaram : OK
# Geocoded:  Vertex Panache, Gachibowli, Outer Ring Road : OK
# Geocoded:  Sri Sairam Sharada, Banjara Hills, NH : OK
# Geocoded:  Miyapur, NH : OK
# Geocoded:  Bikshapathi Nagar: OK
# Geocoded:  My Home Avatar, Narsingi, Outer Ring Road : OK
# Geocoded:  Gandhi Nagar, Kavadiguda, NH : OK
# Geocoded:  Golden Heights Colony, Janachaitanya colony, Hyderabad Expressway : OK
# Geocoded:  Sri Nainas Sunrise, Manikonda, Outer Ring Road : OK
# Geocoded:  NGRI, Secunderabad : OK
# Geocoded:  Mehdipatnam : OK
# Geocoded:  ARK Homes, Bolarum, Medchal Road : OK
# Geocoded:  Narapally : OK
# Completed 100 of 1171 address
# Geocoded:  RDB Coconut Grove, Miyapur, NH : OK
# Geocoded:  New Bowenpally, NH : OK
# Geocoded:  Karwan : OK
# Geocoded:  Ramanthapur, NH : OK
# Geocoded:  Hafeezpet, NH : OK
# Geocoded:  Nizampet : OK
# Geocoded:  Alkapuri, LB Nagar, NH : OK
# Geocoded:  Vidyanagar, Adikmet : OK
# Geocoded:  Adibatla : OK
# Geocoded:  Aparna Sarovar Grande, Nallagandla, Serilingampally : OK
# Geocoded:  Maruthi Nagar : OK
# Geocoded:  Narsingi: OK
# Geocoded:  My Home Avatar, Narsingi, Outer Ring Road : OK
# Geocoded:  Kondapur: OK
# Geocoded:  My Home Avatar, Narsingi, Outer Ring Road : OK
# Geocoded:  Swarnandhra Colony, Secunderabad : OK
# Geocoded:  Concrete Palazzo, Raghavendra Nagar-Nacharam : OK
# Geocoded:  Rajapushpa Atria, Gachibowli, Outer Ring Road : OK
# Geocoded:  Puppalaguda: OK
# Geocoded:  Near Habsiguda Metro Station : OK
# Geocoded:  Bommarillu Apartments, Manikonda, Outer Ring Road : OK
# Geocoded:  D Address, Hitech City : OK
# Geocoded:  Accurate Wind Chimes, Narsingi, Outer Ring Road : OK
# Geocoded:  Aditya Empress Towers, Shaikpet : OK
# Geocoded:  Miyapur, NH : OK
# Geocoded:  Kalyan Puri, Secunderabad : OK
# Geocoded:  Aparna Hill park Silver oaks, Bandam Kommu : OK
# Geocoded:  Gachibowli, Outer Ring Road : OK
# Geocoded:  Sivaji Nagar-Chandanagar : OK
# Geocoded:  Nallagandla, Serilingampally : OK
# Geocoded:  Beeramguda, Ramachandra Puram, NH : OK
# Geocoded:  Kokapet, Outer Ring Road : OK
# Geocoded:  Sai Aishwarya Layout-Manikonda : OK
# Geocoded:  Manikonda, Outer Ring Road : OK
# Geocoded:  Kondapur : OK
# Geocoded:  My Home Avatar, Narsingi, Outer Ring Road : OK
# Geocoded:  Rainbow Vistas Rock Gardens, Hitech City : OK
# Geocoded:  Beeramguda, Ramachandra Puram, NH : OK
# Geocoded:  Uppal Kalan : OK
# Geocoded:  Gachibowli, Outer Ring Road : OK
# Geocoded:  Medipally : OK
# Geocoded:  Lodha Casa Paradiso, Sanath Nagar, NH : OK
# Error geocoding  : ZERO_RESULTS
# Geocoded:  : ZERO_RESULTS
# Geocoded:  Hafeezpet, NH : OK
# Geocoded:  Banjara Hills, NH : OK
# Geocoded:  Chatta Bazaar, Pathar Gatti : OK
# Geocoded:  Hyderabad : OK
# Geocoded:  Bachupally, Outer Ring Road : OK
# Geocoded:  Upparpally, Hyderabad Expressway : OK
# Geocoded:  Bandlaguda Jagir : OK
# Geocoded:  Amulya Heights, Kushaiguda : OK
# Geocoded:  Madinaguda, Hafeezpet, NH : OK
# Geocoded:  Anand Nagar-Khairatabad, NH : OK
# Geocoded:  Godavari Homes, Quthbullapur : OK
# Geocoded:  Sadbhavana, Ghatkesar, NH : OK
# Geocoded:  Aditya Empress Towers, Shaikpet : OK
# Geocoded:  Aditya Empress Towers, Shaikpet : OK
# Geocoded:  Masab Tank : OK
# Geocoded:  Puppalaguda : OK
# Geocoded:  Attapur : OK
# Geocoded:  Pearl Celestial, Kokapet, Outer Ring Road : OK
# Geocoded:  Bairagiguda : OK
# Geocoded:  Aditya Empress Towers, Shaikpet : OK
# Geocoded:  Kukatpally, NH : OK
# Geocoded:  My Home Avatar, Narsingi, Outer Ring Road : OK
# Geocoded:  Bhavyas Tulasi Vanam, Kukatpally, NH : OK
# Geocoded:  Miyapur, NH : OK
# Geocoded:  Serilingampally : OK
# Geocoded:  Samathanagar Addagutta : OK
# Geocoded:  SM Plaza, ECIL : OK
# Geocoded:  Lacasa K Apartments, Banjara Hills, NH : OK
# Geocoded:  Nallagandla, Serilingampally : OK
# Geocoded:  Gayathri Nagar : OK
# Geocoded:  SMR Vinay Harmony County, Appa junction : OK
# Geocoded:  Manikonda, Outer Ring Road : OK
# Geocoded:  Pragathi Nagar, Kukatpally : OK
# Geocoded:  LB Nagar, NH : OK
# Geocoded:  Kokapet, Outer Ring Road : OK
# Geocoded:  Shaikpet: OK
# Geocoded:  Kukatpally Housing Board Colony, NH : OK
# Geocoded:  Aparna CyberLife, Nallagandla, Serilingampally : OK
# Geocoded:  Jeedimetla, NH : OK
# Geocoded:  Ashoka Liviano, Gachibowli, Outer Ring Road : OK
# Geocoded:  Hafeezpet, NH : OK
# Geocoded:  My Home Avatar, My home avatar : OK
# Geocoded:  Trendset Winz, Gachibowli, Outer Ring Road : OK
# Geocoded:  Vajras Jasmine County, Gachibowli, Outer Ring Road : OK
# Geocoded:  Infocity Excellence and Elegance, Nallagandla, Serilingampally : OK
# Geocoded:  Tilak Nagar, New Nallakunta, NH : OK
# Geocoded:  Hyder Shah Kote, Chevella Road : OK
# Geocoded:  Bachupally, Outer Ring Road : OK
# Geocoded:  Lodha Meridian, Malaysian Township, Kukatpally : OK
# Geocoded:  Aditya Imperial Heights, Hafeezpet, NH : OK
# Geocoded:  Indralok Complex, Banjara Hills, NH : OK
# Geocoded:  Aarambh Township, Chandanagar, NH : OK
# Geocoded:  Kondapur : OK
# Geocoded:  Puppalaguda : OK
# Geocoded:  Accurate Wind Chimes, Narsingi, Outer Ring Road : OK
# Geocoded:  SMR Vinay Iconia, Kondapur : OK
# Geocoded:  Miyapur, NH : OK
# Completed 200 of 1171 address
# Geocoded:  Boduppal, NH : OK
# Geocoded:  Rainbow Vistas, Hitech City : OK
# Geocoded:  Rajiv gandhi Nagar-Gachibowli : OK
# Geocoded:  Kavuri Hills, Madhapur : OK
# Geocoded:  Toli Chowki : OK
# Geocoded:  Silicon Ridge, Attapur : OK
# Geocoded:  Gks Habitat Royale, Yapral : OK
# Geocoded:  Kukatpally Housing Board Colony, NH : OK
# Geocoded:  Bhavani: OK
# Geocoded:  Brindavan Colony-Toli Chowki : OK
# Geocoded:  Empress Heights, Jubilee Hills : OK
# Geocoded:  Attapur : OK
# Geocoded:  Mayur Marg : OK
# Geocoded:  Suchitra Circle : OK
# Geocoded:  Masab Tank : OK
# Geocoded:  Mantri Celestia, Gachibowli, Outer Ring Road : OK
# Geocoded:  SMR Vinay Symphony, Gachibowli, Outer Ring Road : OK
# Geocoded:  Project Hill Ridge Springs, Gachibowli, Outer Ring Road : OK
# Geocoded:  NSK Exotica, Kukatpally, NH : OK
# Geocoded:  Sri Ram Nagar Colony, Banjara Hills : OK
# Geocoded:  Badangpet : OK
# Geocoded:  Gachibowli, Outer Ring Road : OK
# Geocoded:  Sumukhi Orbit, Madhapur : OK
# Geocoded:  Manjeera Heights, LB Nagar, NH : OK
# Geocoded:  My Nest Mahati, Kondapur : OK
# Geocoded:  Riyasat Nagar : OK
# Geocoded:  ACE Atlantis, Khaja Guda, Outer Ring Road : OK
# Geocoded:  My Home Vihanga, Gachibowli, Outer Ring Road : OK
# Geocoded:  Toli Chowki : OK
# Geocoded:  Aditya Empress Towers, Shaikpet : OK
# Geocoded:  Attapur : OK
# Geocoded:  Puppalaguda : OK
# Geocoded:  Bachupally, Outer Ring Road : OK
# Geocoded:  Shaikpet : OK
# Geocoded:  Rainbow Vistas Rock Gardens, Hitech City : OK
# Geocoded:  Maruthi Nagar-Dr A.S. Rao Nagar : OK
# Geocoded:  Bhagyalaxmi Nagar, Kavadiguda : OK
# Geocoded:  Nizampet : OK
# Geocoded:  Manikonda, Outer Ring Road : OK
# Geocoded:  Gachibowli, Outer Ring Road : OK
# Geocoded:  Peerzadiguda, NH : OK
# Geocoded:  Rajendra Nagar, Outer Ring Road : OK
# Geocoded:  Pragathi Nagar, Kukatpally : OK
# Geocoded:  Samatha Nagar, Kukatpally, NH : OK
# Geocoded:  Kalimandir, Bandlaguda : OK
# Geocoded:  Suchitra Circle : OK
# Geocoded:  NCC Urban One, Narsingi, Outer Ring Road : OK
# Geocoded:  Langar Houz : OK
# Geocoded:  Papulguda : OK
# Geocoded:  Attapur : OK
# Geocoded:  Nizampet : OK
# Geocoded:  MLA Colony: OK
# Geocoded:  Lodha Meridian, Kukatpally Housing Board Colony, NH : OK
# Geocoded:  Meenakshi Homes, Miyapur, NH : OK
# Geocoded:  Bachupally, Outer Ring Road : OK
# Geocoded:  Bahadurpura, NH : OK
# Geocoded:  ALEAP Industrial Area : OK
# Geocoded:  Toli Chowki : OK
# Geocoded:  Toli: OK
# Geocoded:  My Home Avatar, Narsingi, Outer Ring Road : OK
# Geocoded:  Chandanagar, NH : OK
# Geocoded:  SMR Vinay Harmony County, Appa junction : OK
# Geocoded:  Kukatpally Housing Board Colony, NH : OK
# Geocoded:  New Mallepally : OK
# Geocoded:  My Home Vihanga, Gachibowli, Outer Ring Road : OK
# Geocoded:  LB Nagar, NH : OK
# Geocoded:  Ramky One Marvel, Kukatpally, NH : OK
# Geocoded:  Nallagandla, Serilingampally : OK
# Geocoded:  Attapur : OK
# Geocoded:  Quthbullapur, NH : OK
# Geocoded:  Papulguda : OK
# Geocoded:  Old Malakpet, NH : OK
# Geocoded:  NCL Ganga, Kompally : OK
# Geocoded:  Golden Heights Colony, Janachaitanya colony, Hyderabad Expressway : OK
# Geocoded:  Aparna Hill Park Avenues, Chandanagar, NH : OK
# Geocoded:  Shaikpet : OK
# Geocoded:  Hitech City : OK
# Geocoded:  Aparna CyberZon, Nallagandla, Serilingampally : OK
# Geocoded:  Pearl Residency, Kondapur : OK
# Geocoded:  Nanakram Guda : OK
# Geocoded:  Gajularamaram : OK
# Geocoded:  Punjagutta, NH : OK
# Geocoded:  Manikonda, Outer Ring Road : OK
# Geocoded:  Aminpur : OK
# Geocoded:  Gowlidoddy: OK
# Geocoded:  Shaikpet : OK
# Geocoded:  Attapur : OK
# Geocoded:  Moosapet, NH : OK
# Geocoded:  Hayathnagar, NH : OK
# Geocoded:  Lodha Meridian, Kukatpally Housing Board Colony, NH : OK
# Geocoded:  Banjara Hills, NH : OK
# Geocoded:  Lakdikapul, NH : OK
# Geocoded:  Hyderaguda-Attapur : OK
# Geocoded:  Samata Colony, Toli Chowki : OK
# Geocoded:  Sangareddy District : OK
# Geocoded:  Gachibowli Phase : OK
# Geocoded:  Machabollaram, Medchal Road : OK
# Geocoded:  SMR Vinay Fountainhead, Miyapur, NH : OK
# Geocoded:  Nizampet : OK
# Geocoded:  New Dilshukh Nagar, NH : OK
# Completed 300 of 1171 address
# Geocoded:  Jains Carlton Creek, Gachibowli, Outer Ring Road : OK
# Geocoded:  Neknampur, Manikonda, Outer Ring Road : OK
# Geocoded:  Gundlapochampally, Outer Ring Road : OK
# Geocoded:  Hitech City : OK
# Geocoded:  Aparna CyberLife, Nallagandla, Serilingampally : OK
# Geocoded:  Banjara Hills, NH : OK
# Geocoded:  Kondapur : OK
# Geocoded:  Green Space Residency, Gajularamaram : OK
# Geocoded:  Uppal, NH : OK
# Geocoded:  Manjeera Trinity Homes, Kukatpally, NH : OK
# Geocoded:  Tarnaka : OK
# Geocoded:  Manasarovar Heights, Lothkunta, Siddipet Road : OK
# Geocoded:  Happy Homes Colony, Hyderabad Expressway : OK
# Geocoded:  Kukatpally Project, Kukatpally Housing Board Colony, NH : OK
# Geocoded:  Aminpur: OK
# Geocoded:  Lodha Meridian, Kukatpally Housing Board Colony, NH : OK
# Geocoded:  Ayyappa Society: OK
# Geocoded:  Green Grace, Gachibowli, Outer Ring Road : OK
# Geocoded:  SMR Vinay Iconia, Kondapur : OK
# Geocoded:  Aparna Sarovar Grande, Nallagandla, Serilingampally : OK
# Geocoded:  Trendset Rythme: OK
# Geocoded:  New Nallakunta : OK
# Geocoded:  Kondapur: OK
# Geocoded:  Rajapushpa Atria: OK
# Geocoded:  Lanco Hills, Manikonda, Outer Ring Road : OK
# Geocoded:  Trendset Rythme, Whitefields : OK
# Geocoded:  Himayath Nagar, NH : OK
# Geocoded:  Solitaire Lake View, Miyapur, NH : OK
# Geocoded:  Rajarajeshwari Nagar, Kondapur : OK
# Geocoded:  Kukatpally Housing Board Colony, NH : OK
# Geocoded:  Radhika Villa, Somajiguda, NH : OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Narayanguda 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				         			            	Ayyappa Society,  			            	 	                	 	                		 					            							          							         	Madhapur 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Masjid Banda 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Vidyanagar: OK
# Geocoded:  									 								 				             				             			             				         			            	Lanco Hills,  			            	 	                	 	                		 					            							          							         	Manikonda, Outer Ring Road 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Error geocoding  									: ZERO_RESULTS
# Geocoded:  									: ZERO_RESULTS
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Kompally 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				         			            	Mantri Celestia,  			            	 	                	 	                		 					            							          							         	Gachibowli, Outer Ring Road 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Error geocoding  									: ZERO_RESULTS
# Geocoded:  									: ZERO_RESULTS
# Geocoded:  									 								 				             				             			             				         			            	Vajras Jasmine County,  			            	 	                	 	                		 					            							          							         	Gachibowli, Outer Ring Road 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Kondapur 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Kondapur 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				         			            	PBEL City,  			            	 	                	 	                		 					            							          							         	Appa junction 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				         			            	Rajapushpa Atria: OK
# Error geocoding  									: ZERO_RESULTS
# Geocoded:  									: ZERO_RESULTS
# Geocoded:  									 								 				             				             			             				         			            	Kondapur: OK
# Error geocoding  									: ZERO_RESULTS
# Geocoded:  									: ZERO_RESULTS
# Geocoded:  									 								 				             				             			             				         			            	My Home Vihanga,  			            	 	                	 	                		 					            							          							         	Gachibowli, Outer Ring Road 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				         			            	Aparna Serene Park,  			            	 	                	 	                		 					            							          							         	Kondapur 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Ameerpet, NH  : OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Whitefields 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Error geocoding  									: ZERO_RESULTS
# Geocoded:  									: ZERO_RESULTS
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Bandari Layout 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Jubilee Hills 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Narayanguda 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				         			            	Aparna Aura,  			            	 	                	 	                		 					            							          							         	Jubilee Hills 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Error geocoding  									: ZERO_RESULTS
# Geocoded:  									: ZERO_RESULTS
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Banjara Hills, NH  : OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Begumpet 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Punjagutta, NH  : OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Manikonda, Outer Ring Road 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Yousufguda, NH  : OK
# Geocoded:  									 								 				             				             			             				         			            	Lanco Hills,  			            	 	                	 	                		 					            							          							         	Manikonda, Outer Ring Road 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Error geocoding  									: ZERO_RESULTS
# Geocoded:  									: ZERO_RESULTS
# Geocoded:  									 								 				             				             			             				         			            	Aparna Serene Park,  			            	 	                	 	                		 					            							          							         	Kondapur 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Vidyanagar: OK
# Geocoded:  									 								 				             				             			             				         			            	Shanthinikethan,  			            	 	                	 	                		 					            							          							         	Whitefields 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Sanjeeva Reddy Nagar, NH  : OK
# Geocoded:  									 								 				             				             			             				         			            	Aditya Imperial Heights,  			            	 	                	 	                		 					            							          							         	Hafeezpet, NH  : OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Brindavan Colony-Toli Chowki 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				         			            	My Homes Jewel,  			            	 	                	 	                		 					            							          							         	Miyapur, NH  : OK
# Geocoded:  									 								 				             				             			             				         			            	PBEL City,  			            	 	                	 	                		 					            							          							         	Appa junction 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				         			            	Aparna Serene Park,  			            	 	                	 	                		 					            							          							         	Kondapur 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				         			            	Western Exotica Project ,  			            	 	                	 	                		 					            							          							         	Kothaguda 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				         			            	Tulip Le Park,  			            	 	                	 	                		 					            							          							         	Kondapur 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Brindavan Colony-Toli Chowki 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							           			        				  			        				 	Hyderabad 			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				         			            	Vishnu Nivas,  			            	 	                	 	                		 					            							          							         	Ameerpet, NH  : OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Attapur 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Almasguda 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Gachibowli, Outer Ring Road 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				         			            	Vajras Jasmine County,  			            	 	                	 	                		 					            							          							         	Gachibowli, Outer Ring Road 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				         			            	NCL Sindhu,  			            	 	                	 	                		 					            							          							         	Kompally 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Gachibowli, Outer Ring Road 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				         			            	SMR Vinay Harmony County,  			            	 	                	 	                		 					            							          							         	Appa junction 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				         			            	Jains Ravi Gayathri Heights,  			            	 	                	 	                		 					            							          							         	Hitech City 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				         			            	SV Brindavanam,  			            	 	                	 	                		 					            							          							         	Boduppal, NH : OK
# Geocoded:  									 								 				             				             			             				         			            	Quadri Happy Homes Paradise,  			            	 	                	 	                		 					            							          							         	Amberpet 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Chandanagar, NH  : OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	SBI Colony-Kothapet 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  New Nallakunta : OK
# Geocoded:  Pranavas Lotus Park, Police Colony-Kondapur : OK
# Geocoded:  Chandanagar, NH : OK
# Geocoded:  SVH Padmavathi Icon, Miyapur, NH : OK
# Geocoded:  Banjara Hills, NH : OK
# Geocoded:  Deepthisri Nagar, NH : OK
# Geocoded:  PBEL City, Appa junction : OK
# Geocoded:  West Marredpally : OK
# Geocoded:  SV Brindavanam, Boduppal, NH : OK
# Completed 400 of 1171 address
# Geocoded:  Bowenpally : OK
# Geocoded:  Manjeera Majestic Homes, Kukatpally, NH : OK
# Geocoded:  Vertex Panache, Gachibowli, Outer Ring Road : OK
# Geocoded:  Habsiguda, NH : OK
# Geocoded:  Gandhi Nagar-Boiguda : OK
# Geocoded:  Mehdipatnam : OK
# Geocoded:  Sameera Sisiram, Kondapur : OK
# Geocoded:  Kondapur : OK
# Geocoded:  Emami Swanlake, Kukatpally, NH : OK
# Geocoded:  Beeramguda, Ramachandra Puram, NH : OK
# Geocoded:  Attapur : OK
# Geocoded:  SMR Vinay Fountainhead, Miyapur, NH : OK
# Geocoded:  Manasarovar Heights, Teachers Colony-Trimulgherry : OK
# Geocoded:  Aditya Nagar, Hafeezpet : OK
# Geocoded:  Raaaps Raaganjali, Nalanda Nagar, Upparpally : OK
# Geocoded:  Lakdikapul, NH : OK
# Geocoded:  Manikonda, Outer Ring Road : OK
# Geocoded:  Mye Villa, Mallapur : OK
# Geocoded:  Chandanagar, NH : OK
# Geocoded:  GK Pride, Yapral : OK
# Geocoded:  Vishnu Saphire, Kondapur : OK
# Geocoded:  Malaysian Township, Kukatpally Housing Board Colony, NH : OK
# Geocoded:  Financial District, Nanakram Guda : OK
# Geocoded:  Miyapur, NH : OK
# Geocoded:  Gachibowli, Outer Ring Road : OK
# Geocoded:  Bandari: OK
# Geocoded:  Hyder Nagar, NH : OK
# Geocoded:  Bandlaguda Jagir : OK
# Geocoded:  Moghalpura: OK
# Geocoded:  SMR Vinay Iconia, Kondapur : OK
# Geocoded:  NCL Sindhu, Satyam Enclave, Komapally, NH : OK
# Geocoded:  Aditya Empress Towers, Shaikpet : OK
# Geocoded:  Concrete Sarigama, Manikonda, Outer Ring Road : OK
# Geocoded:  Mohan Nagar, Kothapet : OK
# Geocoded:  Aditya Empress Towers, Shaikpet : OK
# Geocoded:  Friends: OK
# Geocoded:  DD Colony, Amberpet : OK
# Geocoded:  Bandari Layout : OK
# Geocoded:  Moosapet, NH : OK
# Geocoded:  New Nallakunta : OK
# Geocoded:  My Home Avatar, Narsingi, Outer Ring Road : OK
# Geocoded:  DD Colony, Amberpet : OK
# Geocoded:  Mehdipatnam : OK
# Geocoded:  Toli Chowki : OK
# Geocoded:  Aditya Imperial Heights, Hafeezpet, NH : OK
# Geocoded:  Bachupally, Outer Ring Road : OK
# Geocoded:  Habsiguda, NH : OK
# Geocoded:  Narapally: OK
# Geocoded:  Pragathi Nagar, Kukatpally : OK
# Geocoded:  Kushaiguda : OK
# Geocoded:  Manasarovar Heights, Trimulgherry : OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Miyapur, NH  : OK
# Geocoded:  									 								 				             				             			             				         			            	Sai Balaji Shelters,  			            	 	                	 	                		 					            							          							         	Kondapur 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				         			            	Rock Cliff,  			            	 	                	 	                		 					            							          							         	Appa junction 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	New Nallakunta 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Habsiguda, NH : OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							           							         	Pupallaguda, Behind Punjabi Dh 							          			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Gayatri Nagar, Medbowli, Inner Ring Road 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Madhapur 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Hyder Nagar, NH  : OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Vivekananda Nagar, Kukatpally, NH  : OK
# Error geocoding  									: ZERO_RESULTS
# Geocoded:  									: ZERO_RESULTS
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Nizampet 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Kondapur 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Error geocoding  									: ZERO_RESULTS
# Geocoded:  									: ZERO_RESULTS
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Kukatpally, NH  : OK
# Geocoded:  									 								 				             				             			             				         			            	Vineyard Mist,  			            	 	                	 	                		 					            							          							         	Sainikpuri 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Old Malakpet, NH  : OK
# Geocoded:  									 								 				             				             			             				         			            	Aliens Elite,  			            	 	                	 	                		 					            							          							         	Miyapur, NH  : OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Nizampet 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Salivahana Colony: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Nacharam 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				         			            	PBEL City,  			            	 	                	 	                		 					            							          							         	Appa junction 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				         			            	Spectra Metro Heights,  			            	 	                	 	                		 					            							          							         	Nagole 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				         			            	Elite Trehan Towers,  			            	 	                	 	                		 					            							          							         	Habsiguda, NH : OK
# Geocoded:  									 								 				             				             			             				         			            	Aparna Hill Park Avenues,  			            	 	                	 	                		 					            							          							         	Chandanagar, NH  : OK
# Geocoded:  									 								 				             				             			             				         			            	Madineni Madhavan Towers,  			            	 	                	 	                		 					            							          							         	Pathancheru 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Huda Complex, Ram Bagh Colony 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				         			            	Shubham Greens,  			            	 	                	 	                		 					            							          							         	Alkapur Township, Manikonda, Outer Ring Road 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				         			            	My Home Avatar,  			            	 	                	 	                		 					            							          							         	Narsingi, Outer Ring Road 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				         			            	Sai Keerthi Estates,  			            	 	                	 	                		 					            							          							         	Chandanagar, NH  : OK
# Geocoded:  Aparna Kanopy Tulip, Kompally : OK
# Geocoded:  Gem Ascentia, Hitex Road, Shilpa Layout : OK
# Geocoded:  Poe Tree, Narsingi, Outer Ring Road : OK
# Geocoded:  Aparna HillPark Lake Breeze, Chandanagar, NH : OK
# Geocoded:  Xeno Pearl, Kondapur : OK
# Geocoded:  Girijas Marvel, Chandanagar, NH : OK
# Geocoded:  Sri Sai Balaji Residency, Tellapur, Outer Ring Road : OK
# Geocoded:  Bowenpally : OK
# Geocoded:  Janapriya Lakefront: OK
# Geocoded:  Floatilla, Neknampur, Manikonda : OK
# Geocoded:  Sai Akhil Habitat, Nizampet : OK
# Geocoded:  ACE Atlantis, Khaja Guda, Outer Ring Road : OK
# Geocoded:  Bandari Layout : OK
# Geocoded:  Alekhya Towers, LB Nagar, NH : OK
# Geocoded:  Kondapur : OK
# Geocoded:  Aparna Kanopy Tulip, Gundlapochampally, Outer Ring Road : OK
# Geocoded:  Rai Durg : OK
# Geocoded:  Hyderabad : OK
# Geocoded:  Narsingi, Outer Ring Road : OK
# Completed 500 of 1171 address
# Geocoded:  Bachupally, Outer Ring Road : OK
# Geocoded:  Aparna Kanopy Tulip, Kompally : OK
# Geocoded:  Panchavati Colony, Peerzadiguda, NH : OK
# Geocoded:  Attapur : OK
# Geocoded:  Madhava Nagar Colony: OK
# Geocoded:  Gandhinagar-Indira Park Road : OK
# Geocoded:  Sri Sai Varshith Residency, Beeramguda, Ramachandra Puram, NH : OK
# Geocoded:  Sri Vidhya Petals, Hitech City : OK
# Geocoded:  Friends Colony : OK
# Geocoded:  NCL Sindhu, Dandamudi Enclave, Jeedimetla : OK
# Geocoded:  Hasanath: OK
# Geocoded:  Puppalaguda : OK
# Geocoded:  Honer Vivantis, Gopanapalli : OK
# Geocoded:  Mallampet, Outer Ring Road : OK
# Geocoded:  SBI Colony-Kothapet : OK
# Geocoded:  Trimulgherry : OK
# Geocoded:  Sai Vardhini Residency, Nizampet : OK
# Geocoded:  Raghavendra Nagar, Hayathnagar, NH : OK
# Geocoded:  Falaknuma: OK
# Geocoded:  Swamy Towers, Hyderguda : OK
# Geocoded:  Uppal, NH : OK
# Geocoded:  Kothaguda : OK
# Geocoded:  Gajularamaram : OK
# Geocoded:  Nizampet : OK
# Geocoded:  RTC Colony-Chandanagar : OK
# Geocoded:  Sree Vensai Towers, Kompally : OK
# Geocoded:  Bandlaguda Jagir : OK
# Geocoded:  Friends Colony : OK
# Geocoded:  NCC Urban One, Narsingi, Outer Ring Road : OK
# Geocoded:  Raheja Vistas, Nacharam : OK
# Geocoded:  Lecturers Colony, Hayathnagar : OK
# Geocoded:  Turkayamjal : OK
# Geocoded:  Honer Vivantis, Gopanapalli : OK
# Geocoded:  Aparna Hill park Silver oaks, Chandanagar, NH : OK
# Geocoded:  Sri Vidhya Petals, Hitech City : OK
# Geocoded:  Toli Chowki : OK
# Geocoded:  Ramky One Marvel, Kukatpally, NH : OK
# Geocoded:  Sri Nagar Colony : OK
# Geocoded:  Yapral : OK
# Geocoded:  Narsingi, Outer Ring Road : OK
# Geocoded:  Lanco Hills, Manikonda, Outer Ring Road : OK
# Geocoded:  Sapthagiri Enclave, Bachupally, Outer Ring Road : OK
# Geocoded:  Financial District, Nanakram Guda : OK
# Geocoded:  Quthbullapur, NH : OK
# Geocoded:  Karmanghat : OK
# Geocoded:  Aliens Elite, Miyapur, NH : OK
# Geocoded:  Vikrampuri-Karkhana : OK
# Geocoded:  Gayatri Nagar, Medbowli, Inner Ring Road : OK
# Geocoded:  Begumpet : OK
# Geocoded:  Shaikpet : OK
# Geocoded:  Chandanagar, NH : OK
# Geocoded:  Serilingampally : OK
# Geocoded:  Chandanagar, NH : OK
# Geocoded:  Toli Chowki : OK
# Geocoded:  Ameerpet, NH : OK
# Geocoded:  Rai Durg : OK
# Geocoded:  Toli Chowki : OK
# Geocoded:  Gangaram, Chandanagar, NH : OK
# Geocoded:  Nanakram Guda : OK
# Geocoded:  Sun City, Bandlaguda, Chevella Road : OK
# Geocoded:  Kapra : OK
# Geocoded:  My Home Avatar, Narsingi, Outer Ring Road : OK
# Geocoded:  Deluxe Colony, Toli Chowki : OK
# Geocoded:  Hafeez Baba Nagar North, Hafiz Baba Nagar : OK
# Geocoded:  Sai Pearl, Madinaguda, Hafeezpet, NH : OK
# Geocoded:  Tangrilla, Manikonda, Outer Ring Road : OK
# Geocoded:  Kakatiya Hills: OK
# Geocoded:  NCL Ganga, Kompally : OK
# Geocoded:  Chandragiri Colony, Secunderabad : OK
# Geocoded:  Rai Durg : OK
# ...
# Geocoded:  Hitech: OK
# Geocoded:  Srinagar Colony, Old Malakpet, NH : OK
# Geocoded:  Shaikpet : OK
# Geocoded:  Mehdipatnam : OK
# Geocoded:  Anand Nagar-Khairatabad, NH : OK
# Geocoded:  Malkajgiri : OK
# Geocoded:  Nanakram Guda : OK
# Geocoded:  Hyderabad : OK
# Completed 1000 of 1171 address
# Geocoded:  Upparpally, Hyderabad Expressway : OK
# Geocoded:  Kistareddypet, Outer Ring Road : OK
# Geocoded:  My Home Avatar, Narsingi, Outer Ring Road : OK
# Geocoded:  Gudimalkapur : OK
# Geocoded:  Old Bowenpally : OK
# Geocoded:  Gollaguda : OK
# Geocoded:  Kondapur RTO : OK
# Geocoded:  Alakapur: OK
# Geocoded:  Asif Nagar : OK
# Geocoded:  Prime Bhadradri Towers, Kukatpally, NH : OK
# Geocoded:  Surya Nagar-Quthbullapur : OK
# Geocoded:  Bhadurpalle : OK
# Geocoded:  Hyderabad : OK
# Geocoded:  Domalguda, Himayath Nagar, NH : OK
# Geocoded:  HMT swarnapuri colony,Miyapur : OK
# Geocoded:  Nanal nagar, Mehdipatnam : OK
# Geocoded:  Hyderabad : OK
# Geocoded:  Dammaiguda : OK
# Geocoded:  Gulshan Colony, Qutub Shahi Tombs : OK
# Geocoded:  Anjaneyanagar Colony: OK
# Geocoded:  safa complex Sivarampalli : OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Bachupally, Outer Ring Road 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Narsingi, Outer Ring Road 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Hafeezpet, NH  : OK
# Error geocoding  									: ZERO_RESULTS
# Geocoded:  									: ZERO_RESULTS
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Bhagya Nagar Colony, Secunderabad 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Pragathi Nagar, Kukatpally 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Error geocoding  									 								 				             				             			             				        	 	                	 	                		 					            							          							           							         	: ZERO_RESULTS
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							           							         	: ZERO_RESULTS
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							           							         	KPHB 							          			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Osman Nagar 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							           							         	Bandlaguda 							          			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							           							         	Whitefield 							          			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Aziz Bagh Colony, Toli Chowki 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							           							         	Aurora Colony 							          			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							           							         	Sai Nagar Colony 							          			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							           							         	Saleem Nagar colony 							          			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Dilsukh Nagar, NH  : OK
# Error geocoding  									 								 				             				             			             				        	 	                	 	                		 					            							          							           							         	diamond hills Shaikpet 							          			        				  						         	         		    		 	           			 						 							 								 					             					            	: ZERO_RESULTS
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							           							         	diamond hills Shaikpet 							          			        				  						         	         		    		 	           			 						 							 								 					             					            	: ZERO_RESULTS
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	New Nallakunta 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Masab Tank 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Pocharam, NH : OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							           							         	Manikonda ou colony 							          			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							           							         	BHEL 							          			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Isnapur, Outer Ring Road 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							           							         	Chilkalguda 							          			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				         			            	My Home Avatar,  			            	 	                	 	                		 					            							          							         	Narsingi, Outer Ring Road 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Narsingi, Outer Ring Road 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Sivaji Nagar-Chandanagar 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Toli Chowki 							          							           			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							           							         	Kismathpur 							          			        				  						         	         		    		 	           			 						 							 								 					             					            	: OK
# Geocoded:  									 								 				             				             			             				        	 	                	 	                		 					            							          							         	Uppal, NH : OK
# Geocoded:  Sun City, Bandlaguda, Chevella Road : OK
# Geocoded:  Attapur : OK
# Geocoded:  Shankar Nagar, Ramachandra Puram, NH : OK
# Geocoded:  Gopal Nagar : OK
# Geocoded:  Kphb phase : OK
# Geocoded:  Madannapet Colony : OK
# Geocoded:  KPHB Colony : OK
# Geocoded:  Troop Bazar : OK
# Geocoded:  Panchavati Colony, Peerzadiguda, NH : OK
# Geocoded:  Nizampet : OK
# Geocoded:  Gayatri Nagar, Medbowli, Inner Ring Road : OK
# Geocoded:  Dammaiguda : OK
# Geocoded:  Almasguda : OK
# Geocoded:  Zahara Nagar : OK
# Geocoded:  abhinandana exotica Manikonda : OK
# Geocoded:  Chandanagar, NH : OK
# Geocoded:  Tellapur, Outer Ring Road : OK
# Geocoded:  Tellapur, Outer Ring Road : OK
# Geocoded:  Medipally : OK
# Geocoded:  Uppal, NH : OK
# Geocoded:  Madinaguda, Hafeezpet, NH : OK
# Geocoded:  Sagar Ring road lb nagar : OK
# Geocoded:  Bikshapathi Nagar: OK
# Geocoded:  Ghatkesar, NH : OK
# Geocoded:  Neknampur, Manikonda, Outer Ring Road : OK
# Geocoded:  Bandlaguda, Nagole : OK
# Geocoded:  Dabeerpura : OK
# Geocoded:  Shilpa Nagar, Secunderabad : OK
# Geocoded:  Financial District, Nanakram Guda : OK
# Geocoded:  Dilsukh Nagar, NH : OK
# Geocoded:  Qutub Shahi Tombs : OK
# Geocoded:  Kalyan Nagar-Moti Nagar : OK
# Geocoded:  Suchitra Circle : OK
# Geocoded:  Kismatpur, Outer Ring Road : OK
# Geocoded:  Bagh Amberpet, Amberpet, NH : OK
# Geocoded:  Narsingi, Outer Ring Road : OK
# Geocoded:  Bachupally, Outer Ring Road : OK
# Geocoded:  Suchitra Circle : OK
# Geocoded:  Peerzadiguda, NH : OK
# Geocoded:  Pragathi Nagar, Kukatpally : OK
# Geocoded:  Prashant Hills, Rai Durg : OK
# Geocoded:  Kamalapuri: OK
# Geocoded:  Kailash Hills, Mahadevpur Colony : OK
# Geocoded:  Attapur : OK
# Geocoded:  Nizampet : OK
# Geocoded:  Bandlaguda, Nagole, Srisailam Highway : OK
# Geocoded:  Miyapur, NH : OK
# Geocoded:  Old Bowenpally : OK
# Geocoded:  Miyapur, NH : OK
# Completed 1100 of 1171 address
# Geocoded:  Bandlaguda Jagir : OK
# Geocoded:  Snehita Hills: OK
# Geocoded:  Gajularamaram : OK
# Geocoded:  Alwal : OK
# Geocoded:  Kukatpally, NH : OK
# Geocoded:  Kukatpally, NH : OK
# Geocoded:  Aminpur : OK
# Geocoded:  Humayunagar : OK
# Geocoded:  Bolarum, Medchal Road : OK
# Geocoded:  Prender Ghast Road : OK
# Geocoded:  Upparpally, Hyderabad Expressway : OK
# Geocoded:  Miyapur, NH : OK
# Geocoded:  Chitrapuri Colony : OK
# Geocoded:  Kokapet, Outer Ring Road : OK
# Geocoded:  Peeramcheru : OK
# Geocoded:  Turkayamjal: OK
# Geocoded:  Nagole: OK
# Geocoded:  Patancheruvu: OK
# Geocoded:  Rajendra Nagar, Outer Ring Road : OK
# Geocoded:  Attapur : OK
# Geocoded:  Alkapuri, LB Nagar, NH : OK
# Geocoded:  Devendra Rocktown, LB Nagar, NH : OK
# Geocoded:  LB Nagar, NH : OK
# Geocoded:  Kamalapuri Colony : OK
# Geocoded:  Uppal, NH : OK
# Geocoded:  Kalimandir, Bandlaguda : OK
# Geocoded:  Boduppal, NH : OK
# Geocoded:  East Marredpally : OK
# Geocoded:  Kukatpally, NH : OK
# Geocoded:  Mayuri Nagar, Miyapur : OK
# Geocoded:  HUDA Techno Enclave, Hitech City : OK
# Geocoded:  Pragati Nagar : OK
# Geocoded:  Langer House : OK
# Geocoded:  Ananth Nagar, Secunderabad : OK
# Geocoded:  Somajiguda, NH : OK
# Geocoded:  SRI SAIRAM Towers, Hafeezpet, NH : OK
# Geocoded:  Pragathi Nagar, Kukatpally : OK
# Geocoded:  Miyapur, NH : OK
# Geocoded:  Madhapur-: OK
# Geocoded:  Suchitra Circle : OK
# Geocoded:  Bachupally, Outer Ring Road : OK
# Geocoded:  Nizampet : OK
# Geocoded:  Manikonda: OK
# Geocoded:  Ameerpet, NH : OK
# Geocoded:  Punjagutta, NH : OK
# Geocoded:  Anand: OK
# Geocoded:  Metro Palmgrove Phase I & II, Somajiguda, NH : OK
# Geocoded:  Shaikpet : OK
# Geocoded:  Navodaya Colony-Kukatpally : OK
# Geocoded:  Pragathi Nagar, Kukatpally : OK
# Geocoded:  Banjara Hills, NH : OK
# Geocoded:  Banjara Hills, NH : OK
# Geocoded:  Friends Colony : OK
# Geocoded:  Somajiguda, NH : OK
# Geocoded:  Aparna Hill park Silver oaks, Chandanagar, NH : OK
# Geocoded:  Nizampet : OK
# Geocoded:  Alwal : OK
# Geocoded:  Srinagar Colony, Old Malakpet, NH : OK
# Geocoded:  Nizampet : OK
# Geocoded:  Sivaji Nagar-Chandanagar : OK
# Geocoded:  Manikonda, Outer Ring Road : OK
# Geocoded:  Chandanagar, NH : OK
# Geocoded:  Begumpet : OK
# Geocoded:  Manikonda, Outer Ring Road : OK
# Geocoded:  Dilsukh Nagar, NH : OK
# Geocoded:  Attapur: OK
# Geocoded:  Banjara Hills, NH : OK
# Geocoded:  Boduppal, NH : OK
# Geocoded:  Chandanagar, NH : OK
# Geocoded:  Murad Nagar, Lal Darwaza, Falaknuma Road : OK
# Geocoded:  Kukatpally, NH : OK
# Finished geocoding all addresses

# %%
data1.head()
# Out:
#   postcode status
# 0              OK
# 1   500084     OK
# 2   500032     OK
# 3              OK
# 4   500050     OK

# %%
data1['postcode']=data1['postcode'].replace("","No code")

# %%
data1
# Out:
#      postcode status
# 0     No code     OK
# 1      500084     OK
# 2      500032     OK
# 3     No code     OK
# 4      500050     OK
# 5     No code     OK
# 6      500032     OK
# 7       59501     OK
# 8      500008     OK
# 9     No code     OK
# 10    No code     OK
# 11    No code     OK
# 12     500072     OK
# 13    No code     OK
# 14    No code     OK
# 15     500089     OK
# 16     500089     OK
# 17    No code     OK
# 18    No code     OK
# 19     500084     OK
# 20     500079     OK
# 21     500032     OK
# 22    No code     OK
# 23     500094     OK
# 24    No code     OK
# 25    No code     OK
# 26     500032     OK
# 27    No code     OK
# 28    No code     OK
# 29    No code     OK
# ...       ...    ...
# 1141  No code     OK
# 1142  No code     OK
# 1143  No code     OK
# 1144  No code     OK
# 1145  No code     OK
# 1146   500082     OK
# 1147  No code     OK
# 1148   500072     OK
# 1149  No code     OK
# 1150   500034     OK
# 1151   500034     OK
# 1152  No code     OK
# 1153  No code     OK
# 1154   500050     OK
# 1155  No code     OK
# 1156  No code     OK
# 1157   500036     OK
# 1158  No code     OK
# 1159   500133     OK
# 1160  No code     OK
# 1161   500050     OK
# 1162  No code     OK
# 1163  No code     OK
# 1164   500060     OK
# 1165  No code     OK
# 1166   500034     OK
# 1167  No code     OK
# 1168   500050     OK
# 1169  No code     OK
# 1170   500090     OK
#
# [1171 rows x 2 columns]

# %%
data['Postal_code']=data1['postcode']

# %%
data.to_csv('output-magicbricks.csv')

# %%
data.head()
# Out:
#    Unnamed: 0                 Bedrooms Bathrooms      Furnishing  \
# 0           0  3 BHK Service Apartment         1     Unfurnished
# 1           1      1 BHK Builder Floor         1     Unfurnished
# 2           2          3 BHK Apartment         1  Semi-Furnished
# 3           3      2 BHK Builder Floor         1  Semi-Furnished
# 4           4          2 BHK Apartment         1     Unfurnished
#
#            Tennants       Area   Price             Locality Postal_code
# 0         Bachelors  1390 sqft  26,000       Hafeezpet, NH      No code
# 1  Bachelors/Family  read more  14,000   Amarnath Residency      500084
# 2            Family  1650 sqft  35,000       Nanakram Guda       500032
# 3         Bachelors  1200 sqft  22,000       Jubilee Hills      No code
# 4         Bachelors  1295 sqft  27,000     Chandanagar, NH       500050

# %% [markdown]
# ##### End-of-Notebook

# %%
# !jupyter nbconvert --to html webscrapping.ipynb
# Out:
# [NbConvertApp] Converting notebook webscrapping.ipynb to html
# [NbConvertApp] Writing 416060 bytes to webscrapping.html
